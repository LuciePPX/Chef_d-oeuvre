# %% [markdown]
# ## **Dans se fichier StatOnBoat.ipynb** <br>
#
# On sait que sur la journée du 11 sept 2014 sur la zone de la rochelle de 9h à 17h il y a eu 21 bâteaux <br>
#
# Le but de ce fichier est donc de se rapporcher de cette valeur grâce à la segmentation de données sur les images 2014
#
# De plus si on affiche ces points sur une cartes ils ne fdoivent pas apparaitre sur une zone terrestre
#
# **Perspectives** Une fois des chiffres cohérents trouvés avec la vérité terrain de 2014, on pourra tracker ces plots
#
# **Données**
#  images : P2P = 65 thersholdt = 0.5 0-360° <br>
# hauteur=2500 #mètres<br>
# longueur=360 #degrés<br>
# taille=4096 #pixels<br>
#
# vérité : #position RADAR /!\ Campagne 2015 appliqué à 2014<br>
# lat = 46.154533<br>
# long = -1.233523<br>

# %% [markdown]
# ### Données

# %%
#position RADAR /!\ Campagne 2015 appliqué à 2014
lat = 46.154533
long = -1.233523

#image 
hauteur=2500 #mètres
longueur=360 #degrés
taille=4096 #pixels

# %% [markdown]
# ### Importations

# %%
from traitementImage import traitement
from trackingOnMap import trackBoat, trackOnMap
from RectToPolaire import polarisation

# %% [markdown]
# ## Traitement des images

# %%
#polarisation("../Image/2014/ImageBestConfig#1")

# %%
#polarisation("../Image/2014/configBest#2")

# %%
#cParImage2014, pParImage2014, seuilRadar= traitement("../Image/2014/ImageBestConfig#1")

# %%
cParImage2024_polaire, pParImage2014_polaire, imageRead, seuilRadar_polaire= traitement("../Image/2014/Polaire2014/avec noir", typeImg='circulaire')
# Out:
# ...
# Lecture des images: 100%|██████████| 67/67 [00:00<00:00, 275.38it/s]
# seuil de viabilité du radar : 10
# Recherche des bateaux: 100%|██████████| 67/67 [00:00<00:00, 460.18it/s]
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# ...

# %%
len(pParImage2014_polaire[0])
# Out:
# 43

# %%
from VisualiserData import visualisation

# %%
visualisation("../Image/2014/Polaire2014/avec noir", typeImg='circulaire', aire=False)
# Out:
# Lecture des images: 100%|██████████| 67/67 [00:00<00:00, 240.55it/s]
# seuil de viabilité du radar : 10
# Recherche des bateaux: 100%|██████████| 67/67 [00:00<00:00, 430.64it/s]
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# (320, 240)
# ...

# %%
len(pParImage2014_polaire)
#print(pParImage2014_polaire)
# Out:
# 67

# %% [markdown]
# ## Tracking des bâteaux détecter sur la première image + apparrition des nouveaux

# %%
#allTrack=trackBoat(pParImage2014)

# %%
#len(allTrack)

# %%
allTrack_polaire=trackBoat(pParImage2014_polaire)
# Out:
# tracking des bâteaux: 100%|██████████| 66/66 [00:00<00:00, 114.05it/s]

# %%
len(allTrack_polaire)
# Out:
# 43

# %%
import copy

# %% [markdown]
# ### réunir les track ou le dernier point est le premier point de 2 tracks se sont proche

# %%
from trackingOnMap import distLatLong
import copy

# %%
# def dernier(liste):
#     for i,elmt in enumerate(reversed(liste)) :
#         print(elmt)
#         if elmt!=None:
#             return liste[-i]
        
# def premier(liste):
#     for i,elmt in enumerate(liste) :
#         if elmt!=None:
#             return liste[i]

# %%
# L=[None,1,2,3,4,None]

# print(premier(L),'dernier',dernier(L))

# %%
# def reunionBoat(allTrack):

#     boatLoc=copy.deepcopy(allTrack)

#     for i,boat1 in enumerate(boatLoc):

#         for boat2 in boatLoc[i:]:

#             if distLatLong(boat1[-1],boat2[0])<10:
#                 boat1=boat1+boat2
#                 boatLoc[i]=boat1
#                 boatLoc.remove(boat2)

#     return boatLoc

# %%
# allTrackbis=reunionBoat(allTrack)

# %% [markdown]
# ## Affichage du tracking sur une maps

# %%
#trackOnMap(allTrack)

# %%
def cirlceLongLat(cx, cy, centreImg, start_point=(46.154533,-1.233523)):
    lat_ref, lon_ref = 46.154533, -1.233523

    # Coordonnées du centre de l'image
    x_center, y_center = centreImg[0], centreImg[1]

    # Coordonnées du point dans l'image que vous souhaitez convertir
    x, y = 150, 250

    # Ajuster les coordonnées du point dans l'image
    delta_x = x - x_center
    delta_y = y - y_center

    # Coordonnées géographiques du point dans l'image
    lat = lat_ref + delta_y * (echelle_lat / hauteur_image)
    lon = lon_ref + delta_x * (echelle_lon / largeur_image)



    return lat,long

# %%
cirlceLongLat(202, 304, (320, 240))
# Out:
# (9.2309066, 0.6064821416666667)

# %%
trackOnMap(allTrack_polaire)
# Out:
# 43 bâteaux affichés sur la carte
# ...
